# %%
import pandas as pd

# %%
dataset = pd.read_csv('salaries.csv')

# %%
dataset.loc[dataset['salary_in_usd'] > 100000]
# Out:
#        work_year experience_level employment_type                 job_title  \
# 0           2024               MI              FT            Data Scientist
# 2           2024               MI              CT            Data Scientist
# 3           2024               MI              CT            Data Scientist
# 4           2024               MI              FT      Data Science Manager
# 5           2024               MI              FT      Data Science Manager
# ...          ...              ...             ...                       ...
# 16488       2021               SE              FT           Data Specialist
# 16489       2020               SE              FT            Data Scientist
# 16490       2021               MI              FT  Principal Data Scientist
# 16491       2020               EN              FT            Data Scientist
# 16493       2021               SE              FT      Data Science Manager
#
# ...

# %%
min_salary = 100000

dataset.loc[dataset['salary_in_usd'] >= min_salary, ['salary_in_usd','employment_type','company_location']].sort_values('salary_in_usd', ascending=False).head(10)
# Out:
#        salary_in_usd employment_type company_location
# 2764          800000              FT               CA
# 3607          774000              FT               MX
# 6366          750000              FT               US
# 7350          750000              FT               US
# 4582          750000              FT               US
# ...              ...             ...              ...
# 885           100000              FT               US
# 14190         100000              FT               US
# 14186         100000              FT               US
# 3775          100000              FT               US
# 16235         100000              FL               US
#
# [12730 rows x 3 columns]
